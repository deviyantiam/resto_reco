# %%
import warnings
warnings.filterwarnings('ignore')
import os
import random
import json
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set()

# %%
# !pip install surprise
# Out:
# Requirement already satisfied: surprise in c:\users\deviy\anaconda3\envs\reco_sy39\lib\site-packages (0.1)
# Requirement already satisfied: scikit-surprise in c:\users\deviy\anaconda3\envs\reco_sy39\lib\site-packages (from surprise) (1.1.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\deviy\anaconda3\envs\reco_sy39\lib\site-packages (from scikit-surprise->surprise) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\deviy\anaconda3\envs\reco_sy39\lib\site-packages (from scikit-surprise->surprise) (1.23.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\deviy\anaconda3\envs\reco_sy39\lib\site-packages (from scikit-surprise->surprise) (1.10.1)

# %%
from surprise import SVD, NMF, NormalPredictor,KNNBasic
from surprise import accuracy, Reader, Dataset, dump 
from surprise.model_selection import cross_validate, GridSearchCV, train_test_split

# %%
# Load review data
reviews_df = pd.read_pickle("nash_reviews.pkl")

# %%
unique_user_ids = reviews_df['user_id'].unique()
resto = reviews_df['business_id'].unique()

# %%
user_map = {unique_user_ids[i]: i + 1 for i in range(len(unique_user_ids))}
resto_map = {resto[i]: i + 1 for i in range(len(resto))}

# %% [markdown]
# ## Preparing data for the surprise library

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(reviews_df[['user_id', 'business_id', 'stars']], reader)

# %%
# Evaluating different algorithms
performance = []
for algo in [SVD(), NMF(), NormalPredictor()]:
    cv_results = cross_validate(algo, data, measures=['RMSE'], cv=3, verbose=False)
    results_df = pd.DataFrame.from_dict(cv_results).mean(axis=0)
    results_df = results_df._append(pd.Series([str(algo).split(' ')[0].split('.')[-1]], index=['Algorithm']))
    performance.append(results_df)

# %%
pd.DataFrame(performance).set_index('Algorithm')
# Out:
#                  test_rmse  fit_time  test_time
# Algorithm
# SVD               1.125784  2.873580   0.821902
# NMF               1.299851  9.856135   1.033674
# NormalPredictor   1.610988  0.344858   0.706753

# %% [markdown]
# ### Pick SVD, as it seems to perform better

# %%
# Grid search for best parameters
param_grid = {'n_factors': [30, 35], 'n_epochs': [20, 25], 'lr_all': [0.001, 0.003], 'reg_all': [0.08, 0.1]}
grid_search = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=3)
grid_search.fit(data)

# %%
best_algo = grid_search.best_estimator['rmse']
print(grid_search.best_score['rmse'])
print(grid_search.best_params['rmse'])
# Out:
# 1.1180152539296662
# {'n_factors': 30, 'n_epochs': 25, 'lr_all': 0.003, 'reg_all': 0.08}

# %%
# Training on the entire dataset
trainset = data.build_full_trainset()
best_algo.fit(trainset)

# %%
# Saving the trained model
file_name = os.path.expanduser('best_algo_dump')
dump.dump(file_name, algo=best_algo)

# %%
# Loading the saved model
_, loaded_best_algo = dump.load(file_name)

# %%
# Try to predict recommendation for each user
user_list = {i:j for i,j in enumerate(reviews_df['user_id'].unique())}

# %%
# Function to get top N recommendations
from collections import defaultdict
def get_top_n(predictions, n=10):
    """Return the top-N recommendation for each user from a set of predictions."""
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]
    return top_n

# %%
len(user_list.values())
# Out:
# 73311

# %%
batch_size = 10000
total_users = len(user_list)

for start_idx in range(0, total_users, batch_size):
    print(start_idx)
    batch_users = list(user_list.keys())[start_idx:start_idx + batch_size]
    anti_testset = []
    fill_value = trainset.global_mean
    for uid in batch_users:
        user_items = [item for (item, _) in trainset.ur[uid]]
        for iid in trainset.all_items():
            if iid not in user_items:
                anti_testset.append((trainset.to_raw_uid(uid), trainset.to_raw_iid(iid), fill_value))
    
    predictions = loaded_best_algo.test(anti_testset)
    top_n_recommendations = get_top_n(predictions, n=5)
    
    with open('rec_test_{}.json'.format(start_idx // batch_size + 1), 'w') as fp:
        json.dump(top_n_recommendations, fp)
    
    print(f"Processing batch {start_idx // batch_size + 1}: {batch_users[:5]} ... {batch_users[-5:]}")
# Out:
# 0
# Processing batch 1: [0, 1, 2, 3, 4] ... [9995, 9996, 9997, 9998, 9999]
# 10000
# Processing batch 2: [10000, 10001, 10002, 10003, 10004] ... [19995, 19996, 19997, 19998, 19999]
# 20000
# Processing batch 3: [20000, 20001, 20002, 20003, 20004] ... [29995, 29996, 29997, 29998, 29999]
# 30000
# Processing batch 4: [30000, 30001, 30002, 30003, 30004] ... [39995, 39996, 39997, 39998, 39999]
# 40000
# Processing batch 5: [40000, 40001, 40002, 40003, 40004] ... [49995, 49996, 49997, 49998, 49999]
# 50000
# Processing batch 6: [50000, 50001, 50002, 50003, 50004] ... [59995, 59996, 59997, 59998, 59999]
# 60000
# Processing batch 7: [60000, 60001, 60002, 60003, 60004] ... [69995, 69996, 69997, 69998, 69999]
# 70000
# Processing batch 8: [70000, 70001, 70002, 70003, 70004] ... [73306, 73307, 73308, 73309, 73310]

# %% [markdown]
# The top predictions for a select few have been saved in rec.json

# %%
nash_restaurants = pd.read_pickle("nash_restaurants.pkl")

# %%
nash_restaurants.head()
# Out:
#                business_id                name               address  \
# 9   bBDDEgkFA1Otx9Lfe7BZUQ      Sonic Drive-In   2312 Dickerson Pike
# 24  4iRzR7OaS-QaSXuvYxEGKA           Super Dog  1160 Gallatin Pike S
# 27  tMkwHmWFUEXrC9ZduonpTg  The Green Pheasant         215 1st Ave S
# 47  lk9IwjZXqUMqqOhM774DtQ    Caviar & Bananas         2031 Broadway
# 89  oaboaRBUgGjbo2kfUIKDLQ    Mike's Ice Cream         129 2nd Ave N
#
#          city state postal_code   latitude  longitude  stars  review_count  \
# 9   Nashville    TN       37207  36.208102 -86.768170    1.5            10
# 24  Nashville    TN       37115  36.248570 -86.719986    4.0             6
# 27  Nashville    TN       37201  36.159886 -86.773197    4.0           161
# 47  Nashville    TN       37203  36.148371 -86.798895    3.5           159
# 89  Nashville    TN       37201  36.162649 -86.775973    4.5           593
#
#     is_open                                         attributes  \
# 9         1  {'RestaurantsAttire': ''casual'', 'Restaurants...
# 24        0  {'RestaurantsReservations': 'False', 'Restaura...
# 27        0  {'RestaurantsGoodForGroups': 'True', 'HappyHou...
# 47        0  {'RestaurantsTakeOut': 'True', 'RestaurantsRes...
# 89        1  {'RestaurantsGoodForGroups': 'True', 'GoodForK...
#
#                                            categories  \
# 9   Ice Cream & Frozen Yogurt, Fast Food, Burgers,...
# 24                              Hot Dogs, Restaurants
# 27                     Restaurants, Japanese, Seafood
# 47  Coffee & Tea, Restaurants, Wine Bars, Bars, Ni...
# 89  Ice Cream & Frozen Yogurt, Coffee & Tea, Resta...
#
#                                                 hours
# 9   {'Monday': '0:0-0:0', 'Tuesday': '6:0-21:0', '...
# 24                                               None
# 27  {'Wednesday': '16:0-22:0', 'Thursday': '16:0-2...
# 47  {'Monday': '7:0-17:0', 'Tuesday': '7:0-17:0', ...
# 89  {'Monday': '8:0-23:0', 'Tuesday': '8:0-23:0', ...

# %%
list(nash_restaurants.postal_code.unique())
# Out:
# ['37207',
#  '37115',
#  '37201',
#  '37203',
#  '37204',
#  '37214',
#  '37209',
#  '37219',
#  '37212',
#  '37211',
#  '37215',
#  '37205',
#  '37243',
#  '37221',
#  '37206',
#  '37228',
#  '37217',
#  '37013',
#  '37208',
#  '37216',
#  '37067',
#  '37220',
#  '37210',
#  '37076',
#  '37026',
#  '28801',
#  '37218',
#  '37011',
#  '37027',
#  '',
#  '37213',
#  '37246',
#  '37232',
#  '37189',
#  '37229',
#  '37138',
#  '32709',
#  '37135',
#  '37024',
#  '37238',
#  '37072']

# %%
zipc=pd.read_csv('us_zip_code.csv')

# %%
zipc['postal code'] = zipc['postal code'].astype(str)

# %%
len(zipc[zipc['postal code'].isin(nash_restaurants.postal_code.unique())])
# Out:
# 40

# %%
len(nash_restaurants.postal_code.unique())
# Out:
# 41

# %%
zipc[zipc['postal code'].isin(nash_restaurants.postal_code.unique())][['postal code','geopoint', 'place name']]
# Out:
#       country code postal code      place name     admin name1 admin code1  \
# 1554            US       32709       Christmas         Florida          FL
# 2744            US       37203       Nashville       Tennessee          TN
# 6984            US       37189    Whites Creek       Tennessee          TN
# 6985            US       37204       Nashville       Tennessee          TN
# 6986            US       37210       Nashville       Tennessee          TN
# 8507            US       37232       Nashville       Tennessee          TN
# 9833            US       37026      Bradyville       Tennessee          TN
# 9837            US       37205       Nashville       Tennessee          TN
# 9838            US       37220       Nashville       Tennessee          TN
# 11893           US       37214       Nashville       Tennessee          TN
# 11894           US       37215       Nashville       Tennessee          TN
# 11895           US       37216       Nashville       Tennessee          TN
# 11896           US       37221       Nashville       Tennessee          TN
# 17413           US       37011         Antioch       Tennessee          TN
# 17414           US       37207       Nashville       Tennessee          TN
# 17415           US       37213       Nashville       Tennessee          TN
# 19085           US       37229       Nashville       Tennessee          TN
# 20297           US       37067        Franklin       Tennessee          TN
# 21933           US       37201       Nashville       Tennessee          TN
# 26542           US       37217       Nashville       Tennessee          TN
# 28402           US       37219       Nashville       Tennessee          TN
# 28998           US       28801       Asheville  North Carolina          NC
# 32216           US       37115         Madison       Tennessee          TN
# 32218           US       37208       Nashville       Tennessee          TN
# 34291           US       37072  Goodlettsville       Tennessee          TN
# 34292           US       37212       Nashville       Tennessee          TN
# 34293           US       37228       Nashville       Tennessee          TN
# 34294           US       37246       Nashville       Tennessee          TN
# 36280           US       37013         Antioch       Tennessee          TN
# 36281           US       37076       Hermitage       Tennessee          TN
# 36282           US       37211       Nashville       Tennessee          TN
# 36307           US       37135     Nolensville       Tennessee          TN
# 37560           US       37209       Nashville       Tennessee          TN
# 37561           US       37218       Nashville       Tennessee          TN
# 37562           US       37243       Nashville       Tennessee          TN
# 39562           US       37238       Nashville       Tennessee          TN
# 39589           US       37024       Brentwood       Tennessee          TN
# 39590           US       37027       Brentwood       Tennessee          TN
# 40221           US       37138     Old Hickory       Tennessee          TN
# 40222           US       37206       Nashville       Tennessee          TN
#
#       admin name2  admin code2  latitude  longitude
# 1554       Orange         95.0   28.5462   -81.0116
# 2744     Davidson         37.0   36.1504   -86.7916
# 6984     Davidson         37.0   36.2744   -86.8292
# 6985     Davidson         37.0   36.1067   -86.7743
# 6986     Davidson         37.0   36.1379   -86.7410
# 8507     Davidson         37.0   36.1866   -86.7852
# 9833       Cannon         15.0   35.7053   -86.0912
# 9837     Davidson         37.0   36.1114   -86.8690
# 9838     Davidson         37.0   36.0641   -86.7697
# 11893    Davidson         37.0   36.1633   -86.6609
# 11894    Davidson         37.0   36.0986   -86.8219
# 11895    Davidson         37.0   36.2125   -86.7257
# 11896    Davidson         37.0   36.0662   -86.9639
# 17413    Davidson         37.0   36.0601   -86.6722
# 17414    Davidson         37.0   36.2195   -86.7740
# 17415    Davidson         37.0   36.1663   -86.7669
# 19085    Davidson         37.0   36.1866   -86.7852
# 20297  Williamson        187.0   35.9121   -86.7655
# 21933    Davidson         37.0   36.1657   -86.7781
# 26542    Davidson         37.0   36.1052   -86.6591
# 28402    Davidson         37.0   36.1678   -86.7837
# 28998    Buncombe         21.0   35.5971   -82.5565
# 32216    Davidson         37.0   36.2604   -86.7046
# 32218    Davidson         37.0   36.1762   -86.8076
# 34291    Davidson         37.0   36.3417   -86.7212
# 34292    Davidson         37.0   36.1337   -86.8006
# 34293    Davidson         37.0   36.1901   -86.8053
# 34294    Davidson         37.0   36.1586   -86.7900
# 36280    Davidson         37.0   36.0595   -86.6592
# 36281    Davidson         37.0   36.1848   -86.6002
# 36282    Davidson         37.0   36.0725   -86.7240
# 36307  Williamson        187.0   35.9307   -86.6829
# 37560    Davidson         37.0   36.1546   -86.8602
# 37561    Davidson         37.0   36.2071   -86.8456
# 37562    Davidson         37.0   36.1650   -86.7821
# 39562    Davidson         37.0   36.1866   -86.7852
# 39589  Williamson        187.0   36.0331   -86.7828
# 39590  Williamson        187.0   36.0063   -86.7909
# 40221    Davidson         37.0   36.2416   -86.6117
# 40222    Davidson         37.0   36.1798   -86.7411

# %%
zipc['geopoint'] = zipc.apply(lambda row: [row['latitude'], row['longitude']], axis=1)

# %%
zipc[zipc['postal code'].isin(nash_restaurants.postal_code.unique())][['postal code','geopoint', 'place name']].to_csv('nash_zip.csv',index=False)
